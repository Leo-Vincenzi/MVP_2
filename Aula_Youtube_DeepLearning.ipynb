# %% [markdown]
# ## Deep Learning - Youtube (João Lira)
#
# ## Deepface - Reconhecimento Facial com Python
#
# ### Hashtag Programação (https://www.youtube.com/watch?v=tjw3HsXuALk)

# %%
# import warnings
# warnings.filterwarnings("ignore")

# Instala ciblioteca DeepFace - utiliza análise pelo método "convolutional neural network (CNN)"
# !pip install DeepFace opencv-python pandas

# Importa bibliotecas DeepFace, CV2 e Matplotlib
from deepface import DeepFace # ferramenta para análise de atributos faciais (idade, gênero, emoção e raça)
import cv2 # ferramenta para trabalhar com imagens
import matplotlib.pyplot as plt
import os # ferramenta para ler arquivos (e infos) do sistema operacional

# Baixa um arquivo
from google.colab import files
print('-')
print(files)
print('-')
# uploaded = files.upload()

imagem = cv2.imread('img1.jpg')
plt.figure(figsize=(7,7))
plt.imshow(imagem[:, :, ::-1])

# Analisando a imagem carregada pelo DeepFace
# analyze_face = DeepFace.analyze(imagem)

# Analisando apenas a idade e emoção da imagem
resultado = DeepFace.analyze(imagem, actions=('age', 'gender', 'race', 'emotion'), enforce_detection=False )

print("inicio")

print(resultado)

print("fim")
# Out:
# ...
# -
# <module 'google.colab.files' from '/usr/local/lib/python3.10/dist-packages/google/colab/files.py'>
# -
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-3f328464f8c9> in <cell line: 22>()
#      20 imagem = cv2.imread('img1.jpg')
#      21 plt.figure(figsize=(7,7))
# ---> 22 plt.imshow(imagem[:, :, ::-1])
#      23
#      24 # Analisando a imagem carregada pelo DeepFace
#
# TypeError: 'NoneType' object is not subscriptable
